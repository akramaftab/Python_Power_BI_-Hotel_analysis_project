# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv(r"hotel_bookings 2.csv")

# %% [markdown]
# # Exploratory Data Analysis and Data Cleaning

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# ...

# %%
df["arrival_date"] = pd.to_datetime(
    df["arrival_date_day_of_month"].astype(str) + "/" +
    df["arrival_date_month"] + "/" +
    df["arrival_date_year"].astype(str),
    format="%d/%B/%Y"
)

# %% [markdown]
# ##combined the separate day, month, and year columns into a single arrival_date column with proper date formatting. This makes any time-series or trend analysis much easier and more reliable going forward.

# %%
df.drop(["agent","company"], axis = 1, inplace = True)
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
    print("-"*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' 'ROU' 'NOR' 'OMN' 'ARG' 'POL' 'DEU'
#  'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST' 'CZE'
#  'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR' 'UKR'
#  'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO' 'ISR'
#  'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM' 'HRV'
#  'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY' 'KWT'
#  'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN' 'SYC'
#  'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB' 'CMR'
# ...

# %% [markdown]
# ##Listed all unique values for each categorical column to quickly review the dataset’s variety and catch any odd entries.

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df = df[df["adr"]< 5000]

# %% [markdown]
# ##Removed extreme outliers from the adr column to keep the analysis focused on typical values and avoid skewed results.

# %% [markdown]
# # Data Analysis and Visualization

# %%
df["is_canceled"].value_counts(normalize = True) * 100
# Out:
# is_canceled
# 0    62.865337
# 1    37.134663
# Name: proportion, dtype: float64

# %%
def can(value):
    if value == 0:
        return "Not cancelled"
    else:
        return "Cancelled"
df["is_canceled"] = df["is_canceled"].apply(can)

# %%
plt.figure(figsize=(4,4))
gb = df.groupby("is_canceled").agg({'is_canceled':"count"})
plt.pie(gb["is_canceled"],labels = gb.index,autopct = "%1.2f%%")
plt.title("Percentage of Reservations Status",fontsize = 10)
plt.show()

# %% [markdown]
#  ##About 63% of hotel reservations were not canceled, while roughly 37% ended up being canceled.

# %%
plt.figure(figsize=(7,5))
ax = sns.countplot( x = "hotel", hue = "is_canceled", data = df)
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[0])
plt.ylabel("Number of Reservations")
plt.title("Reservations Status by hotels", fontsize = 10)
plt.legend(title="Reservation Status", bbox_to_anchor = (1,1))
plt.show()

# %% [markdown]
# ##City hotels had both higher total bookings and a much higher cancellation count compared to resort hotels.

# %%
resort_hotel = df[df["hotel"] == "Resort Hotel"]
resort_hotel["is_canceled"].value_counts(normalize = True)*100
# Out:
# is_canceled
# Not cancelled    72.024952
# Cancelled        27.975048
# Name: proportion, dtype: float64

# %%
city_hotel = df[df["hotel"] == "City Hotel"]
city_hotel["is_canceled"].value_counts(normalize = True)*100
# Out:
# is_canceled
# Not cancelled    58.291825
# Cancelled        41.708175
# Name: proportion, dtype: float64

# %%
resort_hotel = resort_hotel.groupby("arrival_date")[["adr"]].mean()
city_hotel = city_hotel.groupby("arrival_date")[["adr"]].mean()

# %%
plt.figure(figsize = (15,4))
plt.title("Average dailry rate in City and Resort Hotel", fontsize = 15)
plt.plot(resort_hotel.index,resort_hotel["adr"], label = "Resort Hotel")
plt.plot(city_hotel.index,city_hotel["adr"], label = "City Hotel")
plt.legend(title="Average Daily Rate", fontsize = 10)
plt.show()

# %% [markdown]
# ##The average daily rate (price) for city hotels was consistently higher and more volatile than for resort hotels, especially during peak periods.

# %%
df["month"] = df["arrival_date"].dt.month
plt.figure(figsize = (12,6))
ax = sns.countplot(x = "month", hue = "is_canceled", data = df)
ax.legend(title="Reservation Status", bbox_to_anchor = (1,1), fontsize = 8)
plt.title("Reservation Status by Month", fontsize = 10)
plt.xlabel("month")
plt.ylabel("No. of reservations")
plt.show()

# %% [markdown]
# ##Most reservations and cancellations happened between March and August, with both dropping noticeably in the winter months like November, December, and January.

# %%
canceled_reservations = df[df["is_canceled"] == "Cancelled"]
monthly_adr = canceled_reservations.groupby("month")[["adr"]].sum().reset_index()
plt.figure(figsize=(9,4))
plt.title("ADR per month")
sns.barplot(x="month", y="adr", data=monthly_adr)
plt.show()

# %% [markdown]
# ##The total monthly ADR from canceled reservations peaked in the summer, especially August, indicating higher booking prices that likely influenced cancellation rates during busy seasons.

# %%
plt.figure(figsize = (9,4))
plt.title("Reservation cancellations by waiting list")
sns.histplot(x="days_in_waiting_list", data = canceled_reservations ,bins = 100)
plt.show()

# %% [markdown]
# ##Almost all cancellations happened at zero days on the waiting list, showing guests who book last-minute are much more likely to cancel.

# %%
def gan(value):
    if value == 0:
        return "New Guests"
    else:
        return "Repeated Guest"
df["is_repeated_guest"] = df["is_repeated_guest"].apply(gan)

# %%
df["is_repeated_guest"].value_counts(normalize = True) * 100
# Out:
# is_repeated_guest
# New Guests        96.79891
# Repeated Guest     3.20109
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(7,5))
ax = sns.countplot( x = "is_repeated_guest", hue = "is_canceled", data = df)
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[0])
plt.ylabel("Number of Reservations")
plt.xlabel("Guest Type")
plt.title("Reservations Status by Guest type", fontsize = 10)
plt.legend(title="Reservation Status", bbox_to_anchor = (1,1))
plt.show()

# %% [markdown]
# ##Cancellations were far more common among new guests than repeat guests; new customers are much more likely to cancel their bookings.

# %%
top_10_country = canceled_reservations["country"].value_counts()[:10]

# %%
plt.figure(figsize = (10,6))
plt.title("Top 10 Countries with Reservations Cancelled", fontsize = 10)
plt.pie(top_10_country, autopct = "%.2f", labels = top_10_country.index)
plt.show()

# %% [markdown]
# ##Portugal accounted for the majority of canceled reservations, with other top countries contributing far less to the total cancellations.

# %%
df["market_segment"].value_counts(normalize = True)*100
# Out:
# market_segment
# Online TA        47.437698
# Offline TA/TO    20.319268
# Groups           16.658116
# Direct           10.469566
# Corporate         4.298679
# Complementary     0.617341
# Aviation          0.199332
# Name: proportion, dtype: float64

# %%
canceled_reservations["market_segment"].value_counts(normalize = True)*100
# Out:
# market_segment
# Online TA        46.969560
# Groups           27.398532
# Offline TA/TO    18.746603
# Direct            4.348614
# Corporate         2.215075
# Complementary     0.203841
# Aviation          0.117775
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot( x = "market_segment", hue = "is_canceled", data = df)
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[0])
plt.ylabel("Number of Reservations")
plt.xlabel("Market Segment")
plt.xticks(rotation = 45)
plt.title("Reservations Status by Market segment", fontsize = 10)
plt.legend(title="Reservation Status", bbox_to_anchor = (1,1))
plt.show()

# %% [markdown]
# ##Online TA and Groups segments led in both total bookings and cancellations, driving the majority of hotel activity compared to other channels.
